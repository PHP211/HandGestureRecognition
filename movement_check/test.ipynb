# %%
import cv2
import os
import mediapipe as mp
import numpy as np

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

def mediapipe_detection(image, holistic_model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = holistic_model.process(image)        # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

def extract_keypoints(results):
    lh = np.array([[res.x, res.y] for res in results.left_hand_landmarks.landmark]) if results.left_hand_landmarks else np.zeros((21, 2))
    return lh

def draw_styled_landmarks(image, results):
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
def normalize_keypoints(keypoints):
    # Kiểm tra nếu có đủ số điểm (21 điểm cho mỗi bàn tay)
    if keypoints.shape[0] != 21:
        raise ValueError(f"Số lượng điểm keypoints không hợp lệ: {keypoints.shape[0]}")

    # Cổ tay là điểm đầu tiên trong keypoints (index 0)
    wrist = keypoints[0]
    
    # Dịch các điểm sao cho cổ tay trở thành gốc tọa độ (0, 0)
    normalized_keypoints = []
    for point in keypoints:
        normalized_point = (point[0] - wrist[0], point[1] - wrist[1])  # Chỉ cần dịch x, y
        normalized_keypoints.append(normalized_point)
    
    # Chuyển sang numpy array để dễ dàng tính toán min và max
    normalized_keypoints = np.array(normalized_keypoints)
    
    # Tính toán min và max cho x và y
    x_min, y_min = np.min(normalized_keypoints, axis=0)
    x_max, y_max = np.max(normalized_keypoints, axis=0)
    
    # Tránh chia cho 0 nếu max - min = 0
    if (x_max - x_min) == 0:
        print("Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.")
        x_min, x_max = 0, 1  # Cứ để giá trị x giữ nguyên, hoặc chọn giá trị mặc định
    if (y_max - y_min) == 0:
        print("Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.")
        y_min, y_max = 0, 1  # Cứ để giá trị y giữ nguyên, hoặc chọn giá trị mặc định
    
    # Chuyển min và max về dạng numpy array để có thể tính toán đúng
    min_vals = np.array([x_min, y_min])
    max_vals = np.array([x_max, y_max])
    
    # Chuẩn hóa về phạm vi [-1, 1]
    normalized_keypoints = 2 * (normalized_keypoints - min_vals) / (max_vals - min_vals) - 1
    
    return normalized_keypoints

# %%
def process_images(data_dir, output_dir):
    # Duyệt qua từng class trong thư mục
    classes = os.listdir(data_dir)
    for action in classes:
        class_folder = os.path.join(data_dir, action)
        if not os.path.isdir(class_folder):
            continue

        # Tạo thư mục lưu keypoints
        npy_class_dir = os.path.join(output_dir, action)
        os.makedirs(npy_class_dir, exist_ok=True)
        print(f"Đang xử lý lớp: {action}")

        # Duyệt qua từng ảnh trong class
        images = [f for f in os.listdir(class_folder) if f.endswith('.jpg')]
        images.sort()  # Đảm bảo xử lý theo thứ tự frame1, frame2, ...
        
        with mp_holistic.Holistic(min_detection_confidence=0.7, min_tracking_confidence=0.7) as holistic:
            for img_idx, image_file in enumerate(images):
                image_path = os.path.join(class_folder, image_file)
                
                # Đọc ảnh
                frame = cv2.imread(image_path)
                if frame is None:
                    print(f"Không thể đọc ảnh: {image_path}")
                    continue

                # Trích xuất đặc trưng
                image, results = mediapipe_detection(frame, holistic)
                keypoints = extract_keypoints(results)
                
                keypoints = normalize_keypoints(keypoints)

                # Lưu đặc trưng vào file .npy
                npy_path = os.path.join(npy_class_dir, f"{img_idx}.npy")
                np.save(npy_path, keypoints)

                print(f"Lớp {action}: Lưu keypoints từ ảnh {image_file} vào {npy_path}")
                
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    cv2.destroyAllWindows()
                    return

    cv2.destroyAllWindows()

# %%
# Cấu trúc thư mục
data_dir = 'data'  # Thư mục chứa các lớp (class1, class2, ...)
output_dir = 'data_normalized'  # Thư mục để lưu keypoints dưới dạng .npy
process_images(data_dir, output_dir)
# Out:
# Đang xử lý lớp: movement
# Lớp movement: Lưu keypoints từ ảnh frame_000.jpg vào data_normalized\movement\0.npy
# Lớp movement: Lưu keypoints từ ảnh frame_001.jpg vào data_normalized\movement\1.npy
# Lớp movement: Lưu keypoints từ ảnh frame_002.jpg vào data_normalized\movement\2.npy
# Lớp movement: Lưu keypoints từ ảnh frame_003.jpg vào data_normalized\movement\3.npy
# Lớp movement: Lưu keypoints từ ảnh frame_004.jpg vào data_normalized\movement\4.npy
# Lớp movement: Lưu keypoints từ ảnh frame_005.jpg vào data_normalized\movement\5.npy
# Lớp movement: Lưu keypoints từ ảnh frame_006.jpg vào data_normalized\movement\6.npy
# Lớp movement: Lưu keypoints từ ảnh frame_007.jpg vào data_normalized\movement\7.npy
# Lớp movement: Lưu keypoints từ ảnh frame_008.jpg vào data_normalized\movement\8.npy
# Lớp movement: Lưu keypoints từ ảnh frame_009.jpg vào data_normalized\movement\9.npy
# Lớp movement: Lưu keypoints từ ảnh frame_010.jpg vào data_normalized\movement\10.npy
# Lớp movement: Lưu keypoints từ ảnh frame_011.jpg vào data_normalized\movement\11.npy
# Lớp movement: Lưu keypoints từ ảnh frame_012.jpg vào data_normalized\movement\12.npy
# Lớp movement: Lưu keypoints từ ảnh frame_013.jpg vào data_normalized\movement\13.npy
# Lớp movement: Lưu keypoints từ ảnh frame_014.jpg vào data_normalized\movement\14.npy
# Lớp movement: Lưu keypoints từ ảnh frame_015.jpg vào data_normalized\movement\15.npy
# Lớp movement: Lưu keypoints từ ảnh frame_016.jpg vào data_normalized\movement\16.npy
# Lớp movement: Lưu keypoints từ ảnh frame_017.jpg vào data_normalized\movement\17.npy
# Lớp movement: Lưu keypoints từ ảnh frame_018.jpg vào data_normalized\movement\18.npy
# Lớp movement: Lưu keypoints từ ảnh frame_019.jpg vào data_normalized\movement\19.npy
# Lớp movement: Lưu keypoints từ ảnh frame_020.jpg vào data_normalized\movement\20.npy
# Lớp movement: Lưu keypoints từ ảnh frame_021.jpg vào data_normalized\movement\21.npy
# Lớp movement: Lưu keypoints từ ảnh frame_022.jpg vào data_normalized\movement\22.npy
# Lớp movement: Lưu keypoints từ ảnh frame_023.jpg vào data_normalized\movement\23.npy
# Lớp movement: Lưu keypoints từ ảnh frame_024.jpg vào data_normalized\movement\24.npy
# Lớp movement: Lưu keypoints từ ảnh frame_025.jpg vào data_normalized\movement\25.npy
# Lớp movement: Lưu keypoints từ ảnh frame_026.jpg vào data_normalized\movement\26.npy
# Lớp movement: Lưu keypoints từ ảnh frame_027.jpg vào data_normalized\movement\27.npy
# Lớp movement: Lưu keypoints từ ảnh frame_028.jpg vào data_normalized\movement\28.npy
# Lớp movement: Lưu keypoints từ ảnh frame_029.jpg vào data_normalized\movement\29.npy
# Lớp movement: Lưu keypoints từ ảnh frame_030.jpg vào data_normalized\movement\30.npy
# Lớp movement: Lưu keypoints từ ảnh frame_031.jpg vào data_normalized\movement\31.npy
# Lớp movement: Lưu keypoints từ ảnh frame_032.jpg vào data_normalized\movement\32.npy
# Lớp movement: Lưu keypoints từ ảnh frame_033.jpg vào data_normalized\movement\33.npy
# Lớp movement: Lưu keypoints từ ảnh frame_034.jpg vào data_normalized\movement\34.npy
# Lớp movement: Lưu keypoints từ ảnh frame_035.jpg vào data_normalized\movement\35.npy
# Lớp movement: Lưu keypoints từ ảnh frame_036.jpg vào data_normalized\movement\36.npy
# Lớp movement: Lưu keypoints từ ảnh frame_037.jpg vào data_normalized\movement\37.npy
# Lớp movement: Lưu keypoints từ ảnh frame_038.jpg vào data_normalized\movement\38.npy
# Lớp movement: Lưu keypoints từ ảnh frame_039.jpg vào data_normalized\movement\39.npy
# Lớp movement: Lưu keypoints từ ảnh frame_040.jpg vào data_normalized\movement\40.npy
# Lớp movement: Lưu keypoints từ ảnh frame_041.jpg vào data_normalized\movement\41.npy
# Lớp movement: Lưu keypoints từ ảnh frame_042.jpg vào data_normalized\movement\42.npy
# Lớp movement: Lưu keypoints từ ảnh frame_043.jpg vào data_normalized\movement\43.npy
# Lớp movement: Lưu keypoints từ ảnh frame_044.jpg vào data_normalized\movement\44.npy
# Lớp movement: Lưu keypoints từ ảnh frame_045.jpg vào data_normalized\movement\45.npy
# Lớp movement: Lưu keypoints từ ảnh frame_046.jpg vào data_normalized\movement\46.npy
# Lớp movement: Lưu keypoints từ ảnh frame_047.jpg vào data_normalized\movement\47.npy
# Lớp movement: Lưu keypoints từ ảnh frame_048.jpg vào data_normalized\movement\48.npy
# Lớp movement: Lưu keypoints từ ảnh frame_049.jpg vào data_normalized\movement\49.npy
# Lớp movement: Lưu keypoints từ ảnh frame_050.jpg vào data_normalized\movement\50.npy
# Lớp movement: Lưu keypoints từ ảnh frame_051.jpg vào data_normalized\movement\51.npy
# Lớp movement: Lưu keypoints từ ảnh frame_052.jpg vào data_normalized\movement\52.npy
# Lớp movement: Lưu keypoints từ ảnh frame_053.jpg vào data_normalized\movement\53.npy
# Lớp movement: Lưu keypoints từ ảnh frame_054.jpg vào data_normalized\movement\54.npy
# Lớp movement: Lưu keypoints từ ảnh frame_055.jpg vào data_normalized\movement\55.npy
# Lớp movement: Lưu keypoints từ ảnh frame_056.jpg vào data_normalized\movement\56.npy
# Lớp movement: Lưu keypoints từ ảnh frame_057.jpg vào data_normalized\movement\57.npy
# Lớp movement: Lưu keypoints từ ảnh frame_058.jpg vào data_normalized\movement\58.npy
# Lớp movement: Lưu keypoints từ ảnh frame_059.jpg vào data_normalized\movement\59.npy
# Lớp movement: Lưu keypoints từ ảnh frame_060.jpg vào data_normalized\movement\60.npy
# Lớp movement: Lưu keypoints từ ảnh frame_061.jpg vào data_normalized\movement\61.npy
# Lớp movement: Lưu keypoints từ ảnh frame_062.jpg vào data_normalized\movement\62.npy
# Lớp movement: Lưu keypoints từ ảnh frame_063.jpg vào data_normalized\movement\63.npy
# Lớp movement: Lưu keypoints từ ảnh frame_064.jpg vào data_normalized\movement\64.npy
# Lớp movement: Lưu keypoints từ ảnh frame_065.jpg vào data_normalized\movement\65.npy
# Lớp movement: Lưu keypoints từ ảnh frame_066.jpg vào data_normalized\movement\66.npy
# Lớp movement: Lưu keypoints từ ảnh frame_067.jpg vào data_normalized\movement\67.npy
# Lớp movement: Lưu keypoints từ ảnh frame_068.jpg vào data_normalized\movement\68.npy
# Lớp movement: Lưu keypoints từ ảnh frame_069.jpg vào data_normalized\movement\69.npy
# Lớp movement: Lưu keypoints từ ảnh frame_070.jpg vào data_normalized\movement\70.npy
# Lớp movement: Lưu keypoints từ ảnh frame_071.jpg vào data_normalized\movement\71.npy
# Lớp movement: Lưu keypoints từ ảnh frame_072.jpg vào data_normalized\movement\72.npy
# Lớp movement: Lưu keypoints từ ảnh frame_073.jpg vào data_normalized\movement\73.npy
# Lớp movement: Lưu keypoints từ ảnh frame_074.jpg vào data_normalized\movement\74.npy
# Lớp movement: Lưu keypoints từ ảnh frame_075.jpg vào data_normalized\movement\75.npy
# Lớp movement: Lưu keypoints từ ảnh frame_076.jpg vào data_normalized\movement\76.npy
# Lớp movement: Lưu keypoints từ ảnh frame_077.jpg vào data_normalized\movement\77.npy
# Lớp movement: Lưu keypoints từ ảnh frame_078.jpg vào data_normalized\movement\78.npy
# Lớp movement: Lưu keypoints từ ảnh frame_079.jpg vào data_normalized\movement\79.npy
# Lớp movement: Lưu keypoints từ ảnh frame_080.jpg vào data_normalized\movement\80.npy
# Lớp movement: Lưu keypoints từ ảnh frame_081.jpg vào data_normalized\movement\81.npy
# Lớp movement: Lưu keypoints từ ảnh frame_082.jpg vào data_normalized\movement\82.npy
# Lớp movement: Lưu keypoints từ ảnh frame_083.jpg vào data_normalized\movement\83.npy
# Lớp movement: Lưu keypoints từ ảnh frame_084.jpg vào data_normalized\movement\84.npy
# Lớp movement: Lưu keypoints từ ảnh frame_085.jpg vào data_normalized\movement\85.npy
# Lớp movement: Lưu keypoints từ ảnh frame_086.jpg vào data_normalized\movement\86.npy
# Lớp movement: Lưu keypoints từ ảnh frame_087.jpg vào data_normalized\movement\87.npy
# Lớp movement: Lưu keypoints từ ảnh frame_088.jpg vào data_normalized\movement\88.npy
# Lớp movement: Lưu keypoints từ ảnh frame_089.jpg vào data_normalized\movement\89.npy
# Lớp movement: Lưu keypoints từ ảnh frame_090.jpg vào data_normalized\movement\90.npy
# Lớp movement: Lưu keypoints từ ảnh frame_091.jpg vào data_normalized\movement\91.npy
# Lớp movement: Lưu keypoints từ ảnh frame_092.jpg vào data_normalized\movement\92.npy
# Lớp movement: Lưu keypoints từ ảnh frame_093.jpg vào data_normalized\movement\93.npy
# Lớp movement: Lưu keypoints từ ảnh frame_094.jpg vào data_normalized\movement\94.npy
# Lớp movement: Lưu keypoints từ ảnh frame_095.jpg vào data_normalized\movement\95.npy
# Lớp movement: Lưu keypoints từ ảnh frame_096.jpg vào data_normalized\movement\96.npy
# Lớp movement: Lưu keypoints từ ảnh frame_097.jpg vào data_normalized\movement\97.npy
# Lớp movement: Lưu keypoints từ ảnh frame_098.jpg vào data_normalized\movement\98.npy
# Lớp movement: Lưu keypoints từ ảnh frame_099.jpg vào data_normalized\movement\99.npy
# Lớp movement: Lưu keypoints từ ảnh frame_100.jpg vào data_normalized\movement\100.npy
# Lớp movement: Lưu keypoints từ ảnh frame_101.jpg vào data_normalized\movement\101.npy
# Lớp movement: Lưu keypoints từ ảnh frame_102.jpg vào data_normalized\movement\102.npy
# Lớp movement: Lưu keypoints từ ảnh frame_103.jpg vào data_normalized\movement\103.npy
# Lớp movement: Lưu keypoints từ ảnh frame_104.jpg vào data_normalized\movement\104.npy
# Lớp movement: Lưu keypoints từ ảnh frame_105.jpg vào data_normalized\movement\105.npy
# Lớp movement: Lưu keypoints từ ảnh frame_106.jpg vào data_normalized\movement\106.npy
# Lớp movement: Lưu keypoints từ ảnh frame_107.jpg vào data_normalized\movement\107.npy
# Lớp movement: Lưu keypoints từ ảnh frame_108.jpg vào data_normalized\movement\108.npy
# Lớp movement: Lưu keypoints từ ảnh frame_109.jpg vào data_normalized\movement\109.npy
# Lớp movement: Lưu keypoints từ ảnh frame_110.jpg vào data_normalized\movement\110.npy
# Lớp movement: Lưu keypoints từ ảnh frame_111.jpg vào data_normalized\movement\111.npy
# Lớp movement: Lưu keypoints từ ảnh frame_112.jpg vào data_normalized\movement\112.npy
# Lớp movement: Lưu keypoints từ ảnh frame_113.jpg vào data_normalized\movement\113.npy
# Lớp movement: Lưu keypoints từ ảnh frame_114.jpg vào data_normalized\movement\114.npy
# Lớp movement: Lưu keypoints từ ảnh frame_115.jpg vào data_normalized\movement\115.npy
# Lớp movement: Lưu keypoints từ ảnh frame_116.jpg vào data_normalized\movement\116.npy
# Lớp movement: Lưu keypoints từ ảnh frame_117.jpg vào data_normalized\movement\117.npy
# Lớp movement: Lưu keypoints từ ảnh frame_118.jpg vào data_normalized\movement\118.npy
# Lớp movement: Lưu keypoints từ ảnh frame_119.jpg vào data_normalized\movement\119.npy
# Lớp movement: Lưu keypoints từ ảnh frame_120.jpg vào data_normalized\movement\120.npy
# Lớp movement: Lưu keypoints từ ảnh frame_121.jpg vào data_normalized\movement\121.npy
# Lớp movement: Lưu keypoints từ ảnh frame_122.jpg vào data_normalized\movement\122.npy
# Lớp movement: Lưu keypoints từ ảnh frame_123.jpg vào data_normalized\movement\123.npy
# Lớp movement: Lưu keypoints từ ảnh frame_124.jpg vào data_normalized\movement\124.npy
# Lớp movement: Lưu keypoints từ ảnh frame_125.jpg vào data_normalized\movement\125.npy
# Lớp movement: Lưu keypoints từ ảnh frame_126.jpg vào data_normalized\movement\126.npy
# Lớp movement: Lưu keypoints từ ảnh frame_127.jpg vào data_normalized\movement\127.npy
# Lớp movement: Lưu keypoints từ ảnh frame_128.jpg vào data_normalized\movement\128.npy
# Lớp movement: Lưu keypoints từ ảnh frame_129.jpg vào data_normalized\movement\129.npy
# Lớp movement: Lưu keypoints từ ảnh frame_130.jpg vào data_normalized\movement\130.npy
# Lớp movement: Lưu keypoints từ ảnh frame_131.jpg vào data_normalized\movement\131.npy
# Lớp movement: Lưu keypoints từ ảnh frame_132.jpg vào data_normalized\movement\132.npy
# Lớp movement: Lưu keypoints từ ảnh frame_133.jpg vào data_normalized\movement\133.npy
# Lớp movement: Lưu keypoints từ ảnh frame_134.jpg vào data_normalized\movement\134.npy
# Lớp movement: Lưu keypoints từ ảnh frame_135.jpg vào data_normalized\movement\135.npy
# Lớp movement: Lưu keypoints từ ảnh frame_136.jpg vào data_normalized\movement\136.npy
# Lớp movement: Lưu keypoints từ ảnh frame_137.jpg vào data_normalized\movement\137.npy
# Lớp movement: Lưu keypoints từ ảnh frame_138.jpg vào data_normalized\movement\138.npy
# Lớp movement: Lưu keypoints từ ảnh frame_139.jpg vào data_normalized\movement\139.npy
# Lớp movement: Lưu keypoints từ ảnh frame_140.jpg vào data_normalized\movement\140.npy
# Lớp movement: Lưu keypoints từ ảnh frame_141.jpg vào data_normalized\movement\141.npy
# Lớp movement: Lưu keypoints từ ảnh frame_142.jpg vào data_normalized\movement\142.npy
# Lớp movement: Lưu keypoints từ ảnh frame_143.jpg vào data_normalized\movement\143.npy
# Lớp movement: Lưu keypoints từ ảnh frame_144.jpg vào data_normalized\movement\144.npy
# Lớp movement: Lưu keypoints từ ảnh frame_145.jpg vào data_normalized\movement\145.npy
# Lớp movement: Lưu keypoints từ ảnh frame_146.jpg vào data_normalized\movement\146.npy
# Lớp movement: Lưu keypoints từ ảnh frame_147.jpg vào data_normalized\movement\147.npy
# Lớp movement: Lưu keypoints từ ảnh frame_148.jpg vào data_normalized\movement\148.npy
# Lớp movement: Lưu keypoints từ ảnh frame_149.jpg vào data_normalized\movement\149.npy
# Lớp movement: Lưu keypoints từ ảnh frame_150.jpg vào data_normalized\movement\150.npy
# Lớp movement: Lưu keypoints từ ảnh frame_151.jpg vào data_normalized\movement\151.npy
# Lớp movement: Lưu keypoints từ ảnh frame_152.jpg vào data_normalized\movement\152.npy
# Lớp movement: Lưu keypoints từ ảnh frame_153.jpg vào data_normalized\movement\153.npy
# Lớp movement: Lưu keypoints từ ảnh frame_154.jpg vào data_normalized\movement\154.npy
# Lớp movement: Lưu keypoints từ ảnh frame_155.jpg vào data_normalized\movement\155.npy
# Lớp movement: Lưu keypoints từ ảnh frame_156.jpg vào data_normalized\movement\156.npy
# Lớp movement: Lưu keypoints từ ảnh frame_157.jpg vào data_normalized\movement\157.npy
# Lớp movement: Lưu keypoints từ ảnh frame_158.jpg vào data_normalized\movement\158.npy
# Lớp movement: Lưu keypoints từ ảnh frame_159.jpg vào data_normalized\movement\159.npy
# Lớp movement: Lưu keypoints từ ảnh frame_160.jpg vào data_normalized\movement\160.npy
# Lớp movement: Lưu keypoints từ ảnh frame_161.jpg vào data_normalized\movement\161.npy
# Lớp movement: Lưu keypoints từ ảnh frame_162.jpg vào data_normalized\movement\162.npy
# Lớp movement: Lưu keypoints từ ảnh frame_163.jpg vào data_normalized\movement\163.npy
# Lớp movement: Lưu keypoints từ ảnh frame_164.jpg vào data_normalized\movement\164.npy
# Lớp movement: Lưu keypoints từ ảnh frame_165.jpg vào data_normalized\movement\165.npy
# Lớp movement: Lưu keypoints từ ảnh frame_166.jpg vào data_normalized\movement\166.npy
# Lớp movement: Lưu keypoints từ ảnh frame_167.jpg vào data_normalized\movement\167.npy
# Lớp movement: Lưu keypoints từ ảnh frame_168.jpg vào data_normalized\movement\168.npy
# Lớp movement: Lưu keypoints từ ảnh frame_169.jpg vào data_normalized\movement\169.npy
# Lớp movement: Lưu keypoints từ ảnh frame_170.jpg vào data_normalized\movement\170.npy
# Lớp movement: Lưu keypoints từ ảnh frame_171.jpg vào data_normalized\movement\171.npy
# Lớp movement: Lưu keypoints từ ảnh frame_172.jpg vào data_normalized\movement\172.npy
# Lớp movement: Lưu keypoints từ ảnh frame_173.jpg vào data_normalized\movement\173.npy
# Lớp movement: Lưu keypoints từ ảnh frame_174.jpg vào data_normalized\movement\174.npy
# Lớp movement: Lưu keypoints từ ảnh frame_175.jpg vào data_normalized\movement\175.npy
# Lớp movement: Lưu keypoints từ ảnh frame_176.jpg vào data_normalized\movement\176.npy
# Lớp movement: Lưu keypoints từ ảnh frame_177.jpg vào data_normalized\movement\177.npy
# Lớp movement: Lưu keypoints từ ảnh frame_178.jpg vào data_normalized\movement\178.npy
# Lớp movement: Lưu keypoints từ ảnh frame_179.jpg vào data_normalized\movement\179.npy
# Lớp movement: Lưu keypoints từ ảnh frame_180.jpg vào data_normalized\movement\180.npy
# Lớp movement: Lưu keypoints từ ảnh frame_181.jpg vào data_normalized\movement\181.npy
# Lớp movement: Lưu keypoints từ ảnh frame_182.jpg vào data_normalized\movement\182.npy
# Lớp movement: Lưu keypoints từ ảnh frame_183.jpg vào data_normalized\movement\183.npy
# Lớp movement: Lưu keypoints từ ảnh frame_184.jpg vào data_normalized\movement\184.npy
# Lớp movement: Lưu keypoints từ ảnh frame_185.jpg vào data_normalized\movement\185.npy
# Lớp movement: Lưu keypoints từ ảnh frame_186.jpg vào data_normalized\movement\186.npy
# Lớp movement: Lưu keypoints từ ảnh frame_187.jpg vào data_normalized\movement\187.npy
# Lớp movement: Lưu keypoints từ ảnh frame_188.jpg vào data_normalized\movement\188.npy
# Lớp movement: Lưu keypoints từ ảnh frame_189.jpg vào data_normalized\movement\189.npy
# Lớp movement: Lưu keypoints từ ảnh frame_190.jpg vào data_normalized\movement\190.npy
# Lớp movement: Lưu keypoints từ ảnh frame_191.jpg vào data_normalized\movement\191.npy
# Lớp movement: Lưu keypoints từ ảnh frame_192.jpg vào data_normalized\movement\192.npy
# Lớp movement: Lưu keypoints từ ảnh frame_193.jpg vào data_normalized\movement\193.npy
# Lớp movement: Lưu keypoints từ ảnh frame_194.jpg vào data_normalized\movement\194.npy
# Lớp movement: Lưu keypoints từ ảnh frame_195.jpg vào data_normalized\movement\195.npy
# Lớp movement: Lưu keypoints từ ảnh frame_196.jpg vào data_normalized\movement\196.npy
# Lớp movement: Lưu keypoints từ ảnh frame_197.jpg vào data_normalized\movement\197.npy
# Lớp movement: Lưu keypoints từ ảnh frame_198.jpg vào data_normalized\movement\198.npy
# Lớp movement: Lưu keypoints từ ảnh frame_199.jpg vào data_normalized\movement\199.npy
# Lớp movement: Lưu keypoints từ ảnh frame_200.jpg vào data_normalized\movement\200.npy
# Lớp movement: Lưu keypoints từ ảnh frame_201.jpg vào data_normalized\movement\201.npy
# Lớp movement: Lưu keypoints từ ảnh frame_202.jpg vào data_normalized\movement\202.npy
# Lớp movement: Lưu keypoints từ ảnh frame_203.jpg vào data_normalized\movement\203.npy
# Lớp movement: Lưu keypoints từ ảnh frame_204.jpg vào data_normalized\movement\204.npy
# Lớp movement: Lưu keypoints từ ảnh frame_205.jpg vào data_normalized\movement\205.npy
# Lớp movement: Lưu keypoints từ ảnh frame_206.jpg vào data_normalized\movement\206.npy
# Lớp movement: Lưu keypoints từ ảnh frame_207.jpg vào data_normalized\movement\207.npy
# Lớp movement: Lưu keypoints từ ảnh frame_208.jpg vào data_normalized\movement\208.npy
# Lớp movement: Lưu keypoints từ ảnh frame_209.jpg vào data_normalized\movement\209.npy
# Lớp movement: Lưu keypoints từ ảnh frame_210.jpg vào data_normalized\movement\210.npy
# Lớp movement: Lưu keypoints từ ảnh frame_211.jpg vào data_normalized\movement\211.npy
# Lớp movement: Lưu keypoints từ ảnh frame_212.jpg vào data_normalized\movement\212.npy
# Lớp movement: Lưu keypoints từ ảnh frame_213.jpg vào data_normalized\movement\213.npy
# Lớp movement: Lưu keypoints từ ảnh frame_214.jpg vào data_normalized\movement\214.npy
# Lớp movement: Lưu keypoints từ ảnh frame_215.jpg vào data_normalized\movement\215.npy
# Lớp movement: Lưu keypoints từ ảnh frame_216.jpg vào data_normalized\movement\216.npy
# Lớp movement: Lưu keypoints từ ảnh frame_217.jpg vào data_normalized\movement\217.npy
# Lớp movement: Lưu keypoints từ ảnh frame_218.jpg vào data_normalized\movement\218.npy
# Lớp movement: Lưu keypoints từ ảnh frame_219.jpg vào data_normalized\movement\219.npy
# Lớp movement: Lưu keypoints từ ảnh frame_220.jpg vào data_normalized\movement\220.npy
# Lớp movement: Lưu keypoints từ ảnh frame_221.jpg vào data_normalized\movement\221.npy
# Lớp movement: Lưu keypoints từ ảnh frame_222.jpg vào data_normalized\movement\222.npy
# Lớp movement: Lưu keypoints từ ảnh frame_223.jpg vào data_normalized\movement\223.npy
# Lớp movement: Lưu keypoints từ ảnh frame_224.jpg vào data_normalized\movement\224.npy
# Lớp movement: Lưu keypoints từ ảnh frame_225.jpg vào data_normalized\movement\225.npy
# Lớp movement: Lưu keypoints từ ảnh frame_226.jpg vào data_normalized\movement\226.npy
# Lớp movement: Lưu keypoints từ ảnh frame_227.jpg vào data_normalized\movement\227.npy
# Lớp movement: Lưu keypoints từ ảnh frame_228.jpg vào data_normalized\movement\228.npy
# Lớp movement: Lưu keypoints từ ảnh frame_229.jpg vào data_normalized\movement\229.npy
# Lớp movement: Lưu keypoints từ ảnh frame_230.jpg vào data_normalized\movement\230.npy
# Lớp movement: Lưu keypoints từ ảnh frame_231.jpg vào data_normalized\movement\231.npy
# Lớp movement: Lưu keypoints từ ảnh frame_232.jpg vào data_normalized\movement\232.npy
# Lớp movement: Lưu keypoints từ ảnh frame_233.jpg vào data_normalized\movement\233.npy
# Lớp movement: Lưu keypoints từ ảnh frame_234.jpg vào data_normalized\movement\234.npy
# Lớp movement: Lưu keypoints từ ảnh frame_235.jpg vào data_normalized\movement\235.npy
# Lớp movement: Lưu keypoints từ ảnh frame_236.jpg vào data_normalized\movement\236.npy
# Lớp movement: Lưu keypoints từ ảnh frame_237.jpg vào data_normalized\movement\237.npy
# Lớp movement: Lưu keypoints từ ảnh frame_238.jpg vào data_normalized\movement\238.npy
# Lớp movement: Lưu keypoints từ ảnh frame_239.jpg vào data_normalized\movement\239.npy
# Lớp movement: Lưu keypoints từ ảnh frame_240.jpg vào data_normalized\movement\240.npy
# Lớp movement: Lưu keypoints từ ảnh frame_241.jpg vào data_normalized\movement\241.npy
# Lớp movement: Lưu keypoints từ ảnh frame_242.jpg vào data_normalized\movement\242.npy
# Lớp movement: Lưu keypoints từ ảnh frame_243.jpg vào data_normalized\movement\243.npy
# Lớp movement: Lưu keypoints từ ảnh frame_244.jpg vào data_normalized\movement\244.npy
# Lớp movement: Lưu keypoints từ ảnh frame_245.jpg vào data_normalized\movement\245.npy
# Lớp movement: Lưu keypoints từ ảnh frame_246.jpg vào data_normalized\movement\246.npy
# Lớp movement: Lưu keypoints từ ảnh frame_247.jpg vào data_normalized\movement\247.npy
# Lớp movement: Lưu keypoints từ ảnh frame_248.jpg vào data_normalized\movement\248.npy
# Lớp movement: Lưu keypoints từ ảnh frame_249.jpg vào data_normalized\movement\249.npy
# Lớp movement: Lưu keypoints từ ảnh frame_250.jpg vào data_normalized\movement\250.npy
# Lớp movement: Lưu keypoints từ ảnh frame_251.jpg vào data_normalized\movement\251.npy
# Lớp movement: Lưu keypoints từ ảnh frame_252.jpg vào data_normalized\movement\252.npy
# Lớp movement: Lưu keypoints từ ảnh frame_253.jpg vào data_normalized\movement\253.npy
# Lớp movement: Lưu keypoints từ ảnh frame_254.jpg vào data_normalized\movement\254.npy
# Lớp movement: Lưu keypoints từ ảnh frame_255.jpg vào data_normalized\movement\255.npy
# Lớp movement: Lưu keypoints từ ảnh frame_256.jpg vào data_normalized\movement\256.npy
# Lớp movement: Lưu keypoints từ ảnh frame_257.jpg vào data_normalized\movement\257.npy
# Lớp movement: Lưu keypoints từ ảnh frame_258.jpg vào data_normalized\movement\258.npy
# Lớp movement: Lưu keypoints từ ảnh frame_259.jpg vào data_normalized\movement\259.npy
# Lớp movement: Lưu keypoints từ ảnh frame_260.jpg vào data_normalized\movement\260.npy
# Lớp movement: Lưu keypoints từ ảnh frame_261.jpg vào data_normalized\movement\261.npy
# Lớp movement: Lưu keypoints từ ảnh frame_262.jpg vào data_normalized\movement\262.npy
# Lớp movement: Lưu keypoints từ ảnh frame_263.jpg vào data_normalized\movement\263.npy
# Lớp movement: Lưu keypoints từ ảnh frame_264.jpg vào data_normalized\movement\264.npy
# Lớp movement: Lưu keypoints từ ảnh frame_265.jpg vào data_normalized\movement\265.npy
# Lớp movement: Lưu keypoints từ ảnh frame_266.jpg vào data_normalized\movement\266.npy
# Lớp movement: Lưu keypoints từ ảnh frame_267.jpg vào data_normalized\movement\267.npy
# Lớp movement: Lưu keypoints từ ảnh frame_268.jpg vào data_normalized\movement\268.npy
# Lớp movement: Lưu keypoints từ ảnh frame_269.jpg vào data_normalized\movement\269.npy
# Lớp movement: Lưu keypoints từ ảnh frame_270.jpg vào data_normalized\movement\270.npy
# Lớp movement: Lưu keypoints từ ảnh frame_271.jpg vào data_normalized\movement\271.npy
# Lớp movement: Lưu keypoints từ ảnh frame_272.jpg vào data_normalized\movement\272.npy
# Lớp movement: Lưu keypoints từ ảnh frame_273.jpg vào data_normalized\movement\273.npy
# Lớp movement: Lưu keypoints từ ảnh frame_274.jpg vào data_normalized\movement\274.npy
# Lớp movement: Lưu keypoints từ ảnh frame_275.jpg vào data_normalized\movement\275.npy
# Lớp movement: Lưu keypoints từ ảnh frame_276.jpg vào data_normalized\movement\276.npy
# Lớp movement: Lưu keypoints từ ảnh frame_277.jpg vào data_normalized\movement\277.npy
# Lớp movement: Lưu keypoints từ ảnh frame_278.jpg vào data_normalized\movement\278.npy
# Lớp movement: Lưu keypoints từ ảnh frame_279.jpg vào data_normalized\movement\279.npy
# Lớp movement: Lưu keypoints từ ảnh frame_280.jpg vào data_normalized\movement\280.npy
# Lớp movement: Lưu keypoints từ ảnh frame_281.jpg vào data_normalized\movement\281.npy
# Lớp movement: Lưu keypoints từ ảnh frame_282.jpg vào data_normalized\movement\282.npy
# Lớp movement: Lưu keypoints từ ảnh frame_283.jpg vào data_normalized\movement\283.npy
# Lớp movement: Lưu keypoints từ ảnh frame_284.jpg vào data_normalized\movement\284.npy
# Lớp movement: Lưu keypoints từ ảnh frame_285.jpg vào data_normalized\movement\285.npy
# Lớp movement: Lưu keypoints từ ảnh frame_286.jpg vào data_normalized\movement\286.npy
# Lớp movement: Lưu keypoints từ ảnh frame_287.jpg vào data_normalized\movement\287.npy
# Lớp movement: Lưu keypoints từ ảnh frame_288.jpg vào data_normalized\movement\288.npy
# Lớp movement: Lưu keypoints từ ảnh frame_289.jpg vào data_normalized\movement\289.npy
# Lớp movement: Lưu keypoints từ ảnh frame_290.jpg vào data_normalized\movement\290.npy
# Lớp movement: Lưu keypoints từ ảnh frame_291.jpg vào data_normalized\movement\291.npy
# Lớp movement: Lưu keypoints từ ảnh frame_292.jpg vào data_normalized\movement\292.npy
# Lớp movement: Lưu keypoints từ ảnh frame_293.jpg vào data_normalized\movement\293.npy
# Lớp movement: Lưu keypoints từ ảnh frame_294.jpg vào data_normalized\movement\294.npy
# Lớp movement: Lưu keypoints từ ảnh frame_295.jpg vào data_normalized\movement\295.npy
# Lớp movement: Lưu keypoints từ ảnh frame_296.jpg vào data_normalized\movement\296.npy
# Lớp movement: Lưu keypoints từ ảnh frame_297.jpg vào data_normalized\movement\297.npy
# Lớp movement: Lưu keypoints từ ảnh frame_298.jpg vào data_normalized\movement\298.npy
# Lớp movement: Lưu keypoints từ ảnh frame_299.jpg vào data_normalized\movement\299.npy
# Lớp movement: Lưu keypoints từ ảnh frame_300.jpg vào data_normalized\movement\300.npy
# Lớp movement: Lưu keypoints từ ảnh frame_301.jpg vào data_normalized\movement\301.npy
# Lớp movement: Lưu keypoints từ ảnh frame_302.jpg vào data_normalized\movement\302.npy
# Lớp movement: Lưu keypoints từ ảnh frame_303.jpg vào data_normalized\movement\303.npy
# Lớp movement: Lưu keypoints từ ảnh frame_304.jpg vào data_normalized\movement\304.npy
# Lớp movement: Lưu keypoints từ ảnh frame_305.jpg vào data_normalized\movement\305.npy
# Lớp movement: Lưu keypoints từ ảnh frame_306.jpg vào data_normalized\movement\306.npy
# Lớp movement: Lưu keypoints từ ảnh frame_307.jpg vào data_normalized\movement\307.npy
# Lớp movement: Lưu keypoints từ ảnh frame_308.jpg vào data_normalized\movement\308.npy
# Lớp movement: Lưu keypoints từ ảnh frame_309.jpg vào data_normalized\movement\309.npy
# Lớp movement: Lưu keypoints từ ảnh frame_310.jpg vào data_normalized\movement\310.npy
# Lớp movement: Lưu keypoints từ ảnh frame_311.jpg vào data_normalized\movement\311.npy
# Lớp movement: Lưu keypoints từ ảnh frame_312.jpg vào data_normalized\movement\312.npy
# Lớp movement: Lưu keypoints từ ảnh frame_313.jpg vào data_normalized\movement\313.npy
# Lớp movement: Lưu keypoints từ ảnh frame_314.jpg vào data_normalized\movement\314.npy
# Lớp movement: Lưu keypoints từ ảnh frame_315.jpg vào data_normalized\movement\315.npy
# Lớp movement: Lưu keypoints từ ảnh frame_316.jpg vào data_normalized\movement\316.npy
# Lớp movement: Lưu keypoints từ ảnh frame_317.jpg vào data_normalized\movement\317.npy
# Lớp movement: Lưu keypoints từ ảnh frame_318.jpg vào data_normalized\movement\318.npy
# Lớp movement: Lưu keypoints từ ảnh frame_319.jpg vào data_normalized\movement\319.npy
# Lớp movement: Lưu keypoints từ ảnh frame_320.jpg vào data_normalized\movement\320.npy
# Lớp movement: Lưu keypoints từ ảnh frame_321.jpg vào data_normalized\movement\321.npy
# Lớp movement: Lưu keypoints từ ảnh frame_322.jpg vào data_normalized\movement\322.npy
# Lớp movement: Lưu keypoints từ ảnh frame_323.jpg vào data_normalized\movement\323.npy
# Lớp movement: Lưu keypoints từ ảnh frame_324.jpg vào data_normalized\movement\324.npy
# Lớp movement: Lưu keypoints từ ảnh frame_325.jpg vào data_normalized\movement\325.npy
# Đang xử lý lớp: other
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_000.jpg vào data_normalized\other\0.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_001.jpg vào data_normalized\other\1.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_002.jpg vào data_normalized\other\2.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_003.jpg vào data_normalized\other\3.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_004.jpg vào data_normalized\other\4.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_005.jpg vào data_normalized\other\5.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_006.jpg vào data_normalized\other\6.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_007.jpg vào data_normalized\other\7.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_008.jpg vào data_normalized\other\8.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_009.jpg vào data_normalized\other\9.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_010.jpg vào data_normalized\other\10.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_011.jpg vào data_normalized\other\11.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_012.jpg vào data_normalized\other\12.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_013.jpg vào data_normalized\other\13.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_014.jpg vào data_normalized\other\14.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_015.jpg vào data_normalized\other\15.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_016.jpg vào data_normalized\other\16.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_017.jpg vào data_normalized\other\17.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_018.jpg vào data_normalized\other\18.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_019.jpg vào data_normalized\other\19.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_020.jpg vào data_normalized\other\20.npy
# Lớp other: Lưu keypoints từ ảnh frame_021.jpg vào data_normalized\other\21.npy
# Lớp other: Lưu keypoints từ ảnh frame_022.jpg vào data_normalized\other\22.npy
# Lớp other: Lưu keypoints từ ảnh frame_023.jpg vào data_normalized\other\23.npy
# Lớp other: Lưu keypoints từ ảnh frame_024.jpg vào data_normalized\other\24.npy
# Lớp other: Lưu keypoints từ ảnh frame_025.jpg vào data_normalized\other\25.npy
# Lớp other: Lưu keypoints từ ảnh frame_026.jpg vào data_normalized\other\26.npy
# Lớp other: Lưu keypoints từ ảnh frame_027.jpg vào data_normalized\other\27.npy
# Lớp other: Lưu keypoints từ ảnh frame_028.jpg vào data_normalized\other\28.npy
# Lớp other: Lưu keypoints từ ảnh frame_029.jpg vào data_normalized\other\29.npy
# Lớp other: Lưu keypoints từ ảnh frame_030.jpg vào data_normalized\other\30.npy
# Lớp other: Lưu keypoints từ ảnh frame_031.jpg vào data_normalized\other\31.npy
# Lớp other: Lưu keypoints từ ảnh frame_032.jpg vào data_normalized\other\32.npy
# Lớp other: Lưu keypoints từ ảnh frame_033.jpg vào data_normalized\other\33.npy
# Lớp other: Lưu keypoints từ ảnh frame_034.jpg vào data_normalized\other\34.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_035.jpg vào data_normalized\other\35.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_036.jpg vào data_normalized\other\36.npy
# Lớp other: Lưu keypoints từ ảnh frame_037.jpg vào data_normalized\other\37.npy
# Lớp other: Lưu keypoints từ ảnh frame_038.jpg vào data_normalized\other\38.npy
# Lớp other: Lưu keypoints từ ảnh frame_039.jpg vào data_normalized\other\39.npy
# Lớp other: Lưu keypoints từ ảnh frame_040.jpg vào data_normalized\other\40.npy
# Lớp other: Lưu keypoints từ ảnh frame_041.jpg vào data_normalized\other\41.npy
# Lớp other: Lưu keypoints từ ảnh frame_042.jpg vào data_normalized\other\42.npy
# Lớp other: Lưu keypoints từ ảnh frame_043.jpg vào data_normalized\other\43.npy
# Lớp other: Lưu keypoints từ ảnh frame_044.jpg vào data_normalized\other\44.npy
# Lớp other: Lưu keypoints từ ảnh frame_045.jpg vào data_normalized\other\45.npy
# Lớp other: Lưu keypoints từ ảnh frame_046.jpg vào data_normalized\other\46.npy
# Lớp other: Lưu keypoints từ ảnh frame_047.jpg vào data_normalized\other\47.npy
# Lớp other: Lưu keypoints từ ảnh frame_048.jpg vào data_normalized\other\48.npy
# Lớp other: Lưu keypoints từ ảnh frame_049.jpg vào data_normalized\other\49.npy
# Lớp other: Lưu keypoints từ ảnh frame_050.jpg vào data_normalized\other\50.npy
# Lớp other: Lưu keypoints từ ảnh frame_051.jpg vào data_normalized\other\51.npy
# Lớp other: Lưu keypoints từ ảnh frame_052.jpg vào data_normalized\other\52.npy
# Lớp other: Lưu keypoints từ ảnh frame_053.jpg vào data_normalized\other\53.npy
# Lớp other: Lưu keypoints từ ảnh frame_054.jpg vào data_normalized\other\54.npy
# Lớp other: Lưu keypoints từ ảnh frame_055.jpg vào data_normalized\other\55.npy
# Lớp other: Lưu keypoints từ ảnh frame_056.jpg vào data_normalized\other\56.npy
# Lớp other: Lưu keypoints từ ảnh frame_057.jpg vào data_normalized\other\57.npy
# Lớp other: Lưu keypoints từ ảnh frame_058.jpg vào data_normalized\other\58.npy
# Lớp other: Lưu keypoints từ ảnh frame_059.jpg vào data_normalized\other\59.npy
# Lớp other: Lưu keypoints từ ảnh frame_060.jpg vào data_normalized\other\60.npy
# Lớp other: Lưu keypoints từ ảnh frame_061.jpg vào data_normalized\other\61.npy
# Lớp other: Lưu keypoints từ ảnh frame_062.jpg vào data_normalized\other\62.npy
# Lớp other: Lưu keypoints từ ảnh frame_063.jpg vào data_normalized\other\63.npy
# Lớp other: Lưu keypoints từ ảnh frame_064.jpg vào data_normalized\other\64.npy
# Lớp other: Lưu keypoints từ ảnh frame_065.jpg vào data_normalized\other\65.npy
# Lớp other: Lưu keypoints từ ảnh frame_066.jpg vào data_normalized\other\66.npy
# Lớp other: Lưu keypoints từ ảnh frame_067.jpg vào data_normalized\other\67.npy
# Lớp other: Lưu keypoints từ ảnh frame_068.jpg vào data_normalized\other\68.npy
# Lớp other: Lưu keypoints từ ảnh frame_069.jpg vào data_normalized\other\69.npy
# Lớp other: Lưu keypoints từ ảnh frame_070.jpg vào data_normalized\other\70.npy
# Lớp other: Lưu keypoints từ ảnh frame_071.jpg vào data_normalized\other\71.npy
# Lớp other: Lưu keypoints từ ảnh frame_072.jpg vào data_normalized\other\72.npy
# Lớp other: Lưu keypoints từ ảnh frame_073.jpg vào data_normalized\other\73.npy
# Lớp other: Lưu keypoints từ ảnh frame_074.jpg vào data_normalized\other\74.npy
# Lớp other: Lưu keypoints từ ảnh frame_075.jpg vào data_normalized\other\75.npy
# Lớp other: Lưu keypoints từ ảnh frame_076.jpg vào data_normalized\other\76.npy
# Lớp other: Lưu keypoints từ ảnh frame_077.jpg vào data_normalized\other\77.npy
# Lớp other: Lưu keypoints từ ảnh frame_078.jpg vào data_normalized\other\78.npy
# Lớp other: Lưu keypoints từ ảnh frame_079.jpg vào data_normalized\other\79.npy
# Lớp other: Lưu keypoints từ ảnh frame_080.jpg vào data_normalized\other\80.npy
# Lớp other: Lưu keypoints từ ảnh frame_081.jpg vào data_normalized\other\81.npy
# Lớp other: Lưu keypoints từ ảnh frame_082.jpg vào data_normalized\other\82.npy
# Lớp other: Lưu keypoints từ ảnh frame_083.jpg vào data_normalized\other\83.npy
# Lớp other: Lưu keypoints từ ảnh frame_084.jpg vào data_normalized\other\84.npy
# Lớp other: Lưu keypoints từ ảnh frame_085.jpg vào data_normalized\other\85.npy
# Lớp other: Lưu keypoints từ ảnh frame_086.jpg vào data_normalized\other\86.npy
# Lớp other: Lưu keypoints từ ảnh frame_087.jpg vào data_normalized\other\87.npy
# Lớp other: Lưu keypoints từ ảnh frame_088.jpg vào data_normalized\other\88.npy
# Lớp other: Lưu keypoints từ ảnh frame_089.jpg vào data_normalized\other\89.npy
# Lớp other: Lưu keypoints từ ảnh frame_090.jpg vào data_normalized\other\90.npy
# Lớp other: Lưu keypoints từ ảnh frame_091.jpg vào data_normalized\other\91.npy
# Lớp other: Lưu keypoints từ ảnh frame_092.jpg vào data_normalized\other\92.npy
# Lớp other: Lưu keypoints từ ảnh frame_093.jpg vào data_normalized\other\93.npy
# Lớp other: Lưu keypoints từ ảnh frame_094.jpg vào data_normalized\other\94.npy
# Lớp other: Lưu keypoints từ ảnh frame_095.jpg vào data_normalized\other\95.npy
# Lớp other: Lưu keypoints từ ảnh frame_096.jpg vào data_normalized\other\96.npy
# Lớp other: Lưu keypoints từ ảnh frame_097.jpg vào data_normalized\other\97.npy
# Lớp other: Lưu keypoints từ ảnh frame_098.jpg vào data_normalized\other\98.npy
# Lớp other: Lưu keypoints từ ảnh frame_099.jpg vào data_normalized\other\99.npy
# Lớp other: Lưu keypoints từ ảnh frame_100.jpg vào data_normalized\other\100.npy
# Lớp other: Lưu keypoints từ ảnh frame_101.jpg vào data_normalized\other\101.npy
# Lớp other: Lưu keypoints từ ảnh frame_102.jpg vào data_normalized\other\102.npy
# Lớp other: Lưu keypoints từ ảnh frame_103.jpg vào data_normalized\other\103.npy
# Lớp other: Lưu keypoints từ ảnh frame_104.jpg vào data_normalized\other\104.npy
# Lớp other: Lưu keypoints từ ảnh frame_105.jpg vào data_normalized\other\105.npy
# Lớp other: Lưu keypoints từ ảnh frame_106.jpg vào data_normalized\other\106.npy
# Lớp other: Lưu keypoints từ ảnh frame_107.jpg vào data_normalized\other\107.npy
# Lớp other: Lưu keypoints từ ảnh frame_108.jpg vào data_normalized\other\108.npy
# Lớp other: Lưu keypoints từ ảnh frame_109.jpg vào data_normalized\other\109.npy
# Lớp other: Lưu keypoints từ ảnh frame_110.jpg vào data_normalized\other\110.npy
# Lớp other: Lưu keypoints từ ảnh frame_111.jpg vào data_normalized\other\111.npy
# Lớp other: Lưu keypoints từ ảnh frame_112.jpg vào data_normalized\other\112.npy
# Lớp other: Lưu keypoints từ ảnh frame_113.jpg vào data_normalized\other\113.npy
# Lớp other: Lưu keypoints từ ảnh frame_114.jpg vào data_normalized\other\114.npy
# Lớp other: Lưu keypoints từ ảnh frame_115.jpg vào data_normalized\other\115.npy
# Lớp other: Lưu keypoints từ ảnh frame_116.jpg vào data_normalized\other\116.npy
# Lớp other: Lưu keypoints từ ảnh frame_117.jpg vào data_normalized\other\117.npy
# Lớp other: Lưu keypoints từ ảnh frame_118.jpg vào data_normalized\other\118.npy
# Lớp other: Lưu keypoints từ ảnh frame_119.jpg vào data_normalized\other\119.npy
# Lớp other: Lưu keypoints từ ảnh frame_120.jpg vào data_normalized\other\120.npy
# Lớp other: Lưu keypoints từ ảnh frame_121.jpg vào data_normalized\other\121.npy
# Lớp other: Lưu keypoints từ ảnh frame_122.jpg vào data_normalized\other\122.npy
# Lớp other: Lưu keypoints từ ảnh frame_123.jpg vào data_normalized\other\123.npy
# Lớp other: Lưu keypoints từ ảnh frame_124.jpg vào data_normalized\other\124.npy
# Lớp other: Lưu keypoints từ ảnh frame_125.jpg vào data_normalized\other\125.npy
# Lớp other: Lưu keypoints từ ảnh frame_126.jpg vào data_normalized\other\126.npy
# Lớp other: Lưu keypoints từ ảnh frame_127.jpg vào data_normalized\other\127.npy
# Lớp other: Lưu keypoints từ ảnh frame_128.jpg vào data_normalized\other\128.npy
# Lớp other: Lưu keypoints từ ảnh frame_129.jpg vào data_normalized\other\129.npy
# Lớp other: Lưu keypoints từ ảnh frame_130.jpg vào data_normalized\other\130.npy
# Lớp other: Lưu keypoints từ ảnh frame_131.jpg vào data_normalized\other\131.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_132.jpg vào data_normalized\other\132.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_133.jpg vào data_normalized\other\133.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_134.jpg vào data_normalized\other\134.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_135.jpg vào data_normalized\other\135.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_136.jpg vào data_normalized\other\136.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_137.jpg vào data_normalized\other\137.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_138.jpg vào data_normalized\other\138.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_139.jpg vào data_normalized\other\139.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_140.jpg vào data_normalized\other\140.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_141.jpg vào data_normalized\other\141.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_142.jpg vào data_normalized\other\142.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_143.jpg vào data_normalized\other\143.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_144.jpg vào data_normalized\other\144.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_145.jpg vào data_normalized\other\145.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_146.jpg vào data_normalized\other\146.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_147.jpg vào data_normalized\other\147.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_148.jpg vào data_normalized\other\148.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_149.jpg vào data_normalized\other\149.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_150.jpg vào data_normalized\other\150.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_151.jpg vào data_normalized\other\151.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_152.jpg vào data_normalized\other\152.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_153.jpg vào data_normalized\other\153.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_154.jpg vào data_normalized\other\154.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_155.jpg vào data_normalized\other\155.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_156.jpg vào data_normalized\other\156.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_157.jpg vào data_normalized\other\157.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_158.jpg vào data_normalized\other\158.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_159.jpg vào data_normalized\other\159.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_160.jpg vào data_normalized\other\160.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_161.jpg vào data_normalized\other\161.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_162.jpg vào data_normalized\other\162.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_163.jpg vào data_normalized\other\163.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_164.jpg vào data_normalized\other\164.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_165.jpg vào data_normalized\other\165.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_166.jpg vào data_normalized\other\166.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_167.jpg vào data_normalized\other\167.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_168.jpg vào data_normalized\other\168.npy
# ...
# Lớp other: Lưu keypoints từ ảnh frame_371.jpg vào data_normalized\other\371.npy
# Lớp other: Lưu keypoints từ ảnh frame_372.jpg vào data_normalized\other\372.npy
# Lớp other: Lưu keypoints từ ảnh frame_373.jpg vào data_normalized\other\373.npy
# Lớp other: Lưu keypoints từ ảnh frame_374.jpg vào data_normalized\other\374.npy
# Lớp other: Lưu keypoints từ ảnh frame_375.jpg vào data_normalized\other\375.npy
# Lớp other: Lưu keypoints từ ảnh frame_376.jpg vào data_normalized\other\376.npy
# Lớp other: Lưu keypoints từ ảnh frame_377.jpg vào data_normalized\other\377.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_378.jpg vào data_normalized\other\378.npy
# Lớp other: Lưu keypoints từ ảnh frame_379.jpg vào data_normalized\other\379.npy
# Lớp other: Lưu keypoints từ ảnh frame_380.jpg vào data_normalized\other\380.npy
# Lớp other: Lưu keypoints từ ảnh frame_381.jpg vào data_normalized\other\381.npy
# Lớp other: Lưu keypoints từ ảnh frame_382.jpg vào data_normalized\other\382.npy
# Lớp other: Lưu keypoints từ ảnh frame_383.jpg vào data_normalized\other\383.npy
# Lớp other: Lưu keypoints từ ảnh frame_384.jpg vào data_normalized\other\384.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_385.jpg vào data_normalized\other\385.npy
# Lớp other: Lưu keypoints từ ảnh frame_386.jpg vào data_normalized\other\386.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_387.jpg vào data_normalized\other\387.npy
# Lớp other: Lưu keypoints từ ảnh frame_388.jpg vào data_normalized\other\388.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_389.jpg vào data_normalized\other\389.npy
# Lớp other: Lưu keypoints từ ảnh frame_390.jpg vào data_normalized\other\390.npy
# Lớp other: Lưu keypoints từ ảnh frame_391.jpg vào data_normalized\other\391.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_392.jpg vào data_normalized\other\392.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_393.jpg vào data_normalized\other\393.npy
# Lớp other: Lưu keypoints từ ảnh frame_394.jpg vào data_normalized\other\394.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_395.jpg vào data_normalized\other\395.npy
# Lớp other: Lưu keypoints từ ảnh frame_396.jpg vào data_normalized\other\396.npy
# Lớp other: Lưu keypoints từ ảnh frame_397.jpg vào data_normalized\other\397.npy
# Lớp other: Lưu keypoints từ ảnh frame_398.jpg vào data_normalized\other\398.npy
# Lớp other: Lưu keypoints từ ảnh frame_399.jpg vào data_normalized\other\399.npy
# Lớp other: Lưu keypoints từ ảnh frame_400.jpg vào data_normalized\other\400.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_401.jpg vào data_normalized\other\401.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_402.jpg vào data_normalized\other\402.npy
# Lớp other: Lưu keypoints từ ảnh frame_403.jpg vào data_normalized\other\403.npy
# Lớp other: Lưu keypoints từ ảnh frame_404.jpg vào data_normalized\other\404.npy
# Lớp other: Lưu keypoints từ ảnh frame_405.jpg vào data_normalized\other\405.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_406.jpg vào data_normalized\other\406.npy
# Lớp other: Lưu keypoints từ ảnh frame_407.jpg vào data_normalized\other\407.npy
# Lớp other: Lưu keypoints từ ảnh frame_408.jpg vào data_normalized\other\408.npy
# Lớp other: Lưu keypoints từ ảnh frame_409.jpg vào data_normalized\other\409.npy
# Lớp other: Lưu keypoints từ ảnh frame_410.jpg vào data_normalized\other\410.npy
# Lớp other: Lưu keypoints từ ảnh frame_411.jpg vào data_normalized\other\411.npy
# Lớp other: Lưu keypoints từ ảnh frame_412.jpg vào data_normalized\other\412.npy
# Lớp other: Lưu keypoints từ ảnh frame_413.jpg vào data_normalized\other\413.npy
# Lớp other: Lưu keypoints từ ảnh frame_414.jpg vào data_normalized\other\414.npy
# Lớp other: Lưu keypoints từ ảnh frame_415.jpg vào data_normalized\other\415.npy
# Lớp other: Lưu keypoints từ ảnh frame_416.jpg vào data_normalized\other\416.npy
# Lớp other: Lưu keypoints từ ảnh frame_417.jpg vào data_normalized\other\417.npy
# Lớp other: Lưu keypoints từ ảnh frame_418.jpg vào data_normalized\other\418.npy
# Lớp other: Lưu keypoints từ ảnh frame_419.jpg vào data_normalized\other\419.npy
# Lớp other: Lưu keypoints từ ảnh frame_420.jpg vào data_normalized\other\420.npy
# Lớp other: Lưu keypoints từ ảnh frame_421.jpg vào data_normalized\other\421.npy
# Lớp other: Lưu keypoints từ ảnh frame_422.jpg vào data_normalized\other\422.npy
# Lớp other: Lưu keypoints từ ảnh frame_423.jpg vào data_normalized\other\423.npy
# Lớp other: Lưu keypoints từ ảnh frame_424.jpg vào data_normalized\other\424.npy
# Lớp other: Lưu keypoints từ ảnh frame_425.jpg vào data_normalized\other\425.npy
# Lớp other: Lưu keypoints từ ảnh frame_426.jpg vào data_normalized\other\426.npy
# Lớp other: Lưu keypoints từ ảnh frame_427.jpg vào data_normalized\other\427.npy
# Lớp other: Lưu keypoints từ ảnh frame_428.jpg vào data_normalized\other\428.npy
# Lớp other: Lưu keypoints từ ảnh frame_429.jpg vào data_normalized\other\429.npy
# Lớp other: Lưu keypoints từ ảnh frame_430.jpg vào data_normalized\other\430.npy
# Lớp other: Lưu keypoints từ ảnh frame_431.jpg vào data_normalized\other\431.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_432.jpg vào data_normalized\other\432.npy
# Lớp other: Lưu keypoints từ ảnh frame_433.jpg vào data_normalized\other\433.npy
# Lớp other: Lưu keypoints từ ảnh frame_434.jpg vào data_normalized\other\434.npy
# Lớp other: Lưu keypoints từ ảnh frame_435.jpg vào data_normalized\other\435.npy
# Lớp other: Lưu keypoints từ ảnh frame_436.jpg vào data_normalized\other\436.npy
# Lớp other: Lưu keypoints từ ảnh frame_437.jpg vào data_normalized\other\437.npy
# Lớp other: Lưu keypoints từ ảnh frame_438.jpg vào data_normalized\other\438.npy
# Lớp other: Lưu keypoints từ ảnh frame_439.jpg vào data_normalized\other\439.npy
# Lớp other: Lưu keypoints từ ảnh frame_440.jpg vào data_normalized\other\440.npy
# Lớp other: Lưu keypoints từ ảnh frame_441.jpg vào data_normalized\other\441.npy
# Lớp other: Lưu keypoints từ ảnh frame_442.jpg vào data_normalized\other\442.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_443.jpg vào data_normalized\other\443.npy
# Lớp other: Lưu keypoints từ ảnh frame_444.jpg vào data_normalized\other\444.npy
# Lớp other: Lưu keypoints từ ảnh frame_445.jpg vào data_normalized\other\445.npy
# Lớp other: Lưu keypoints từ ảnh frame_446.jpg vào data_normalized\other\446.npy
# Lớp other: Lưu keypoints từ ảnh frame_447.jpg vào data_normalized\other\447.npy
# Lớp other: Lưu keypoints từ ảnh frame_448.jpg vào data_normalized\other\448.npy
# Lớp other: Lưu keypoints từ ảnh frame_449.jpg vào data_normalized\other\449.npy
# Lớp other: Lưu keypoints từ ảnh frame_450.jpg vào data_normalized\other\450.npy
# Lớp other: Lưu keypoints từ ảnh frame_451.jpg vào data_normalized\other\451.npy
# Lớp other: Lưu keypoints từ ảnh frame_452.jpg vào data_normalized\other\452.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_453.jpg vào data_normalized\other\453.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_454.jpg vào data_normalized\other\454.npy
# Lớp other: Lưu keypoints từ ảnh frame_455.jpg vào data_normalized\other\455.npy
# Lớp other: Lưu keypoints từ ảnh frame_456.jpg vào data_normalized\other\456.npy
# Lớp other: Lưu keypoints từ ảnh frame_457.jpg vào data_normalized\other\457.npy
# Lớp other: Lưu keypoints từ ảnh frame_458.jpg vào data_normalized\other\458.npy
# Lớp other: Lưu keypoints từ ảnh frame_459.jpg vào data_normalized\other\459.npy
# Lớp other: Lưu keypoints từ ảnh frame_460.jpg vào data_normalized\other\460.npy
# Lớp other: Lưu keypoints từ ảnh frame_461.jpg vào data_normalized\other\461.npy
# Lớp other: Lưu keypoints từ ảnh frame_462.jpg vào data_normalized\other\462.npy
# Lớp other: Lưu keypoints từ ảnh frame_463.jpg vào data_normalized\other\463.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_464.jpg vào data_normalized\other\464.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_465.jpg vào data_normalized\other\465.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_466.jpg vào data_normalized\other\466.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_467.jpg vào data_normalized\other\467.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_468.jpg vào data_normalized\other\468.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_469.jpg vào data_normalized\other\469.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_470.jpg vào data_normalized\other\470.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_471.jpg vào data_normalized\other\471.npy
# Lớp other: Lưu keypoints từ ảnh frame_472.jpg vào data_normalized\other\472.npy
# Lớp other: Lưu keypoints từ ảnh frame_473.jpg vào data_normalized\other\473.npy
# Lớp other: Lưu keypoints từ ảnh frame_474.jpg vào data_normalized\other\474.npy
# Lớp other: Lưu keypoints từ ảnh frame_475.jpg vào data_normalized\other\475.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_476.jpg vào data_normalized\other\476.npy
# Lớp other: Lưu keypoints từ ảnh frame_477.jpg vào data_normalized\other\477.npy
# Lớp other: Lưu keypoints từ ảnh frame_478.jpg vào data_normalized\other\478.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_479.jpg vào data_normalized\other\479.npy
# Lớp other: Lưu keypoints từ ảnh frame_480.jpg vào data_normalized\other\480.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_481.jpg vào data_normalized\other\481.npy
# Lớp other: Lưu keypoints từ ảnh frame_482.jpg vào data_normalized\other\482.npy
# Lớp other: Lưu keypoints từ ảnh frame_483.jpg vào data_normalized\other\483.npy
# Lớp other: Lưu keypoints từ ảnh frame_484.jpg vào data_normalized\other\484.npy
# Lớp other: Lưu keypoints từ ảnh frame_485.jpg vào data_normalized\other\485.npy
# Lớp other: Lưu keypoints từ ảnh frame_486.jpg vào data_normalized\other\486.npy
# Lớp other: Lưu keypoints từ ảnh frame_487.jpg vào data_normalized\other\487.npy
# Lớp other: Lưu keypoints từ ảnh frame_488.jpg vào data_normalized\other\488.npy
# Lớp other: Lưu keypoints từ ảnh frame_489.jpg vào data_normalized\other\489.npy
# Lớp other: Lưu keypoints từ ảnh frame_490.jpg vào data_normalized\other\490.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_491.jpg vào data_normalized\other\491.npy
# Lớp other: Lưu keypoints từ ảnh frame_492.jpg vào data_normalized\other\492.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_493.jpg vào data_normalized\other\493.npy
# Lớp other: Lưu keypoints từ ảnh frame_494.jpg vào data_normalized\other\494.npy
# Lớp other: Lưu keypoints từ ảnh frame_495.jpg vào data_normalized\other\495.npy
# Lớp other: Lưu keypoints từ ảnh frame_496.jpg vào data_normalized\other\496.npy
# Lớp other: Lưu keypoints từ ảnh frame_497.jpg vào data_normalized\other\497.npy
# Lớp other: Lưu keypoints từ ảnh frame_498.jpg vào data_normalized\other\498.npy
# Lớp other: Lưu keypoints từ ảnh frame_499.jpg vào data_normalized\other\499.npy
# Lớp other: Lưu keypoints từ ảnh frame_500.jpg vào data_normalized\other\500.npy
# Lớp other: Lưu keypoints từ ảnh frame_501.jpg vào data_normalized\other\501.npy
# Lớp other: Lưu keypoints từ ảnh frame_502.jpg vào data_normalized\other\502.npy
# Lớp other: Lưu keypoints từ ảnh frame_503.jpg vào data_normalized\other\503.npy
# Lớp other: Lưu keypoints từ ảnh frame_504.jpg vào data_normalized\other\504.npy
# Lớp other: Lưu keypoints từ ảnh frame_505.jpg vào data_normalized\other\505.npy
# Lớp other: Lưu keypoints từ ảnh frame_506.jpg vào data_normalized\other\506.npy
# Lớp other: Lưu keypoints từ ảnh frame_507.jpg vào data_normalized\other\507.npy
# Lớp other: Lưu keypoints từ ảnh frame_508.jpg vào data_normalized\other\508.npy
# Lớp other: Lưu keypoints từ ảnh frame_509.jpg vào data_normalized\other\509.npy
# Lớp other: Lưu keypoints từ ảnh frame_510.jpg vào data_normalized\other\510.npy
# Lớp other: Lưu keypoints từ ảnh frame_511.jpg vào data_normalized\other\511.npy
# Lớp other: Lưu keypoints từ ảnh frame_512.jpg vào data_normalized\other\512.npy
# Lớp other: Lưu keypoints từ ảnh frame_513.jpg vào data_normalized\other\513.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_514.jpg vào data_normalized\other\514.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_515.jpg vào data_normalized\other\515.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_516.jpg vào data_normalized\other\516.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_517.jpg vào data_normalized\other\517.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_518.jpg vào data_normalized\other\518.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_519.jpg vào data_normalized\other\519.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_520.jpg vào data_normalized\other\520.npy
# Cảnh báo: Tọa độ x không thay đổi, bỏ qua chuẩn hóa x.
# Cảnh báo: Tọa độ y không thay đổi, bỏ qua chuẩn hóa y.
# Lớp other: Lưu keypoints từ ảnh frame_521.jpg vào data_normalized\other\521.npy
